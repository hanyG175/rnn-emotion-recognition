# %%
import sys
sys.path.append('..')

# %%
# Get the dataframes
import pandas as pd

train_df = pd.read_parquet("train-00000-of-00001.parquet")
val_df   = pd.read_parquet("validation-00000-of-00001.parquet")
test_df  = pd.read_parquet("test-00000-of-00001.parquet")

# %%
train_df.head()
# Out:
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Preprocess text data
from src.rnn_pipeline.data.preprocess_text import TextPreprocessor

preprocessor = TextPreprocessor(min_freq=2)
preprocessor.fit(train_df)
train_df = preprocessor.transform(train_df)

preprocessor.save("artifacts/vocab.json")

# # Just transform test/validation data 
# vocab = preprocessor.load("artifacts/vocab.json")

# val_df = preprocessor.transform(val_df)
# test_df = preprocessor.transform(test_df)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create the Dataset Instance with the DataLoader
from src.rnn_pipeline.data.datasets import TextDataset
from src.rnn_pipeline.data.loaders import get_text_loader

dataset = TextDataset(train_df, max_len=50)
train_loader = get_text_loader(dataset, batch_size=32, shuffle=True)

val_dataset = TextDataset(val_df, max_len=50)
val_loader = get_text_loader(val_dataset, batch_size=256, shuffle=False)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Train the model
from src.rnn_pipeline.train import train_rnn_model

vocab_size = len(vocab)
embed_dim = 100
hidden_dim = 256
num_classes = train_df["label"].nunique()
num_epochs = 14
lr = 0.01
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Train the model
# ----> 2 from src.rnn_pipeline.train import train_rnn_model
#       4 vocab_size = len(vocab)
#       5 embed_dim = 100
#
# File c:\Users\LENOVO\Code\ML\emotion recognition mlops\emotion-recognition-mlops\notebooks\..\src\rnn_pipeline\train.py:1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#
# File c:\Python312\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
# ...
